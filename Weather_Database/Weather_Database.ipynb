# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create 2000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 758

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# ng Record 6 of Set 7 | yarim
# Processing Record 7 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 7 | mahajanga
# Processing Record 9 of Set 7 | naze
# Processing Record 10 of Set 7 | evensk
# Processing Record 11 of Set 7 | ouesso
# Processing Record 12 of Set 7 | payson
# Processing Record 13 of Set 7 | sunel
# Processing Record 14 of Set 7 | komsomolskiy
# Processing Record 15 of Set 7 | russkiy aktash
# Processing Record 16 of Set 7 | shirpur
# Processing Record 17 of Set 7 | tarko-sale
# Processing Record 18 of Set 7 | ucluelet
# Processing Record 19 of Set 7 | shetpe
# Processing Record 20 of Set 7 | alpena
# Processing Record 21 of Set 7 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 22 of Set 7 | praia
# Processing Record 23 of Set 7 | brownsville
# Processing Record 24 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 25 of Set 7 | vostok
# Processing Record 26 of Set 7 | rio gallegos
# Processing Record 27 of Set 7 | dehloran
# Processing Record 28 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 30 of Set 7 | kirakira
# Processing Record 31 of Set 7 | mezen
# Processing Record 32 of Set 7 | san policarpo
# Processing Record 33 of Set 7 | aras
# Processing Record 34 of Set 7 | atar
# Processing Record 35 of Set 7 | tyup
# Processing Record 36 of Set 7 | boat of garten
# Processing Record 37 of Set 7 | laguna
# Processing Record 38 of Set 7 | follonica
# Processing Record 39 of Set 7 | baksheyevo
# Processing Record 40 of Set 7 | huangzhou
# Processing Record 41 of Set 7 | manokwari
# Processing Record 42 of Set 7 | sorong
# Processing Record 43 of Set 7 | cavalcante
# Processing Record 44 of Set 7 | saint george
# Processing Record 45 of Set 7 | jodhpur
# Processing Record 46 of Set 7 | dingle
# Processing Record 47 of Set 7 | veinticinco de mayo
# Processing Record 48 of Set 7 | chanute
# Processing Record 49 of Set 7 | talnakh
# Processing Record 50 of Set 7 | aginskoye
# Processing Record 1 of Set 8 | buritis
# Processing Record 2 of Set 8 | la orilla
# Processing Record 3 of Set 8 | corner brook
# Processing Record 4 of Set 8 | tolmachevo
# Processing Record 5 of Set 8 | trinidad
# Processing Record 6 of Set 8 | ipil
# Processing Record 7 of Set 8 | tecoanapa
# Processing Record 8 of Set 8 | vestmannaeyjar
# Processing Record 9 of Set 8 | lubango
# Processing Record 10 of Set 8 | belyy yar
# Processing Record 11 of Set 8 | zeya
# Processing Record 12 of Set 8 | casablanca
# Processing Record 13 of Set 8 | puerto del rosario
# Processing Record 14 of Set 8 | ribas do rio pardo
# Processing Record 15 of Set 8 | klyuchi
# Processing Record 16 of Set 8 | kokstad
# Processing Record 17 of Set 8 | hue
# Processing Record 18 of Set 8 | saint-pierre
# Processing Record 19 of Set 8 | ishigaki
# Processing Record 20 of Set 8 | maghama
# City not found. Skipping...
# Processing Record 21 of Set 8 | kodiak
# Processing Record 22 of Set 8 | houma
# Processing Record 23 of Set 8 | nhulunbuy
# Processing Record 24 of Set 8 | morondava
# Processing Record 25 of Set 8 | san juan
# Processing Record 26 of Set 8 | coihaique
# Processing Record 27 of Set 8 | chinsali
# Processing Record 28 of Set 8 | flin flon
# Processing Record 29 of Set 8 | mayo
# Processing Record 30 of Set 8 | kristiinankaupunki
# Processing Record 31 of Set 8 | avera
# Processing Record 32 of Set 8 | puro
# Processing Record 33 of Set 8 | monreale
# Processing Record 34 of Set 8 | hervey bay
# Processing Record 35 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 36 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 37 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 38 of Set 8 | yamada
# Processing Record 39 of Set 8 | tambopata
# Processing Record 40 of Set 8 | kristiansund
# Processing Record 41 of Set 8 | sheridan
# Processing Record 42 of Set 8 | honavar
# Processing Record 43 of Set 8 | lavrentiya
# Processing Record 44 of Set 8 | sheffield lake
# Processing Record 45 of Set 8 | sindand
# City not found. Skipping...
# Processing Record 46 of Set 8 | ayagoz
# Processing Record 47 of Set 8 | la plata
# Processing Record 48 of Set 8 | kahului
# Processing Record 49 of Set 8 | saldanha
# Processing Record 50 of Set 8 | quatre cocos
# Processing Record 1 of Set 9 | puerto narino
# Processing Record 2 of Set 9 | taoudenni
# Processing Record 3 of Set 9 | rottweil
# Processing Record 4 of Set 9 | yongzhou
# Processing Record 5 of Set 9 | sitka
# Processing Record 6 of Set 9 | wana
# Processing Record 7 of Set 9 | balsas
# Processing Record 8 of Set 9 | evanston
# Processing Record 9 of Set 9 | alofi
# Processing Record 10 of Set 9 | shimoda
# Processing Record 11 of Set 9 | yatou
# Processing Record 12 of Set 9 | braedstrup
# Processing Record 13 of Set 9 | malakal
# Processing Record 14 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 9 | qom
# Processing Record 16 of Set 9 | west wendover
# Processing Record 17 of Set 9 | hay river
# Processing Record 18 of Set 9 | joshimath
# Processing Record 19 of Set 9 | caiaponia
# Processing Record 20 of Set 9 | luena
# Processing Record 21 of Set 9 | vardo
# Processing Record 22 of Set 9 | padang
# Processing Record 23 of Set 9 | pierre
# Processing Record 24 of Set 9 | cabedelo
# Processing Record 25 of Set 9 | kankaanpaa
# Processing Record 26 of Set 9 | berlevag
# Processing Record 27 of Set 9 | buariki
# City not found. Skipping...
# Processing Record 28 of Set 9 | courtenay
# Processing Record 29 of Set 9 | poya
# Processing Record 30 of Set 9 | tadine
# Processing Record 31 of Set 9 | marzuq
# Processing Record 32 of Set 9 | luanda
# Processing Record 33 of Set 9 | chopovychi
# Processing Record 34 of Set 9 | aloleng
# Processing Record 35 of Set 9 | uglich
# Processing Record 36 of Set 9 | erdenet
# Processing Record 37 of Set 9 | viransehir
# Processing Record 38 of Set 9 | jaru
# Processing Record 39 of Set 9 | barroualie
# City not found. Skipping...
# Processing Record 40 of Set 9 | saint-louis
# Processing Record 41 of Set 9 | emerald
# Processing Record 42 of Set 9 | istisu
# Processing Record 43 of Set 9 | harbin
# Processing Record 44 of Set 9 | kieta
# Processing Record 45 of Set 9 | konstantinovka
# Processing Record 46 of Set 9 | bikaner
# Processing Record 47 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 9 | tabou
# Processing Record 49 of Set 9 | paoua
# Processing Record 50 of Set 9 | america dourada
# Processing Record 1 of Set 10 | kenai
# Processing Record 2 of Set 10 | alvaraes
# Processing Record 3 of Set 10 | tautira
# Processing Record 4 of Set 10 | kualakapuas
# Processing Record 5 of Set 10 | matagami
# Processing Record 6 of Set 10 | wuzhou
# Processing Record 7 of Set 10 | ahuimanu
# Processing Record 8 of Set 10 | homer
# Processing Record 9 of Set 10 | weiser
# Processing Record 10 of Set 10 | martapura
# Processing Record 11 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 12 of Set 10 | airai
# Processing Record 13 of Set 10 | meiktila
# Processing Record 14 of Set 10 | kimbe
# Processing Record 15 of Set 10 | skagastrond
# City not found. Skipping...
# Processing Record 16 of Set 10 | grindavik
# Processing Record 17 of Set 10 | anchorage
# Processing Record 18 of Set 10 | erenhot
# Processing Record 19 of Set 10 | dharmadam
# Processing Record 20 of Set 10 | mwense
# Processing Record 21 of Set 10 | kyzyl-suu
# Processing Record 22 of Set 10 | marseille
# Processing Record 23 of Set 10 | melo
# Processing Record 24 of Set 10 | doka
# Processing Record 25 of Set 10 | sinazongwe
# Processing Record 26 of Set 10 | gawler
# Processing Record 27 of Set 10 | ouadda
# Processing Record 28 of Set 10 | huarmey
# Processing Record 29 of Set 10 | woodbury
# Processing Record 30 of Set 10 | sokoto
# Processing Record 31 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 32 of Set 10 | innisfail
# Processing Record 33 of Set 10 | sao joao evangelista
# Processing Record 34 of Set 10 | shalinskoye
# Processing Record 35 of Set 10 | santa cruz cabralia
# Processing Record 36 of Set 10 | paracuru
# Processing Record 37 of Set 10 | nizhniy tsasuchey
# Processing Record 38 of Set 10 | manta
# Processing Record 39 of Set 10 | killarney
# Processing Record 40 of Set 10 | kampong cham
# Processing Record 41 of Set 10 | batagay-alyta
# Processing Record 42 of Set 10 | butterworth
# Processing Record 43 of Set 10 | cayenne
# Processing Record 44 of Set 10 | abapo
# Processing Record 45 of Set 10 | reus
# Processing Record 46 of Set 10 | juneau
# Processing Record 47 of Set 10 | sambava
# Processing Record 48 of Set 10 | inyonga
# Processing Record 49 of Set 10 | morant bay
# Processing Record 50 of Set 10 | garden city
# Processing Record 1 of Set 11 | coquimbo
# Processing Record 2 of Set 11 | west plains
# Processing Record 3 of Set 11 | bayir
# Processing Record 4 of Set 11 | piacabucu
# Processing Record 5 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 6 of Set 11 | korem
# Processing Record 7 of Set 11 | miri
# Processing Record 8 of Set 11 | tolaga bay
# Processing Record 9 of Set 11 | barra
# Processing Record 10 of Set 11 | touros
# Processing Record 11 of Set 11 | sistranda
# Processing Record 12 of Set 11 | copiapo
# Processing Record 13 of Set 11 | nizwa
# Processing Record 14 of Set 11 | trincomalee
# Processing Record 15 of Set 11 | srednekolymsk
# Processing Record 16 of Set 11 | gazanjyk
# Processing Record 17 of Set 11 | rosario
# Processing Record 18 of Set 11 | mnogovershinnyy
# Processing Record 19 of Set 11 | matay
# Processing Record 20 of Set 11 | whitehorse
# Processing Record 21 of Set 11 | synya
# Processing Record 22 of Set 11 | yangambi
# Processing Record 23 of Set 11 | hun
# Processing Record 24 of Set 11 | la paz
# Processing Record 25 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 11 | klaksvik
# Processing Record 27 of Set 11 | uyuni
# Processing Record 28 of Set 11 | hovd
# Processing Record 29 of Set 11 | cam ranh
# Processing Record 30 of Set 11 | williamsport
# Processing Record 31 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 32 of Set 11 | iranshahr
# Processing Record 33 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 11 | palana
# Processing Record 35 of Set 11 | portland
# Processing Record 36 of Set 11 | eyl
# Processing Record 37 of Set 11 | khash
# Processing Record 38 of Set 11 | filingue
# Processing Record 39 of Set 11 | portel
# Processing Record 40 of Set 11 | luwingu
# Processing Record 41 of Set 11 | crystal beach
# Processing Record 42 of Set 11 | lashio
# Processing Record 43 of Set 11 | rorvik
# Processing Record 44 of Set 11 | amuntai
# Processing Record 45 of Set 11 | phnum penh
# City not found. Skipping...
# Processing Record 46 of Set 11 | indramayu
# Processing Record 47 of Set 11 | salinopolis
# Processing Record 48 of Set 11 | rivadavia
# Processing Record 49 of Set 11 | concepcion del oro
# Processing Record 50 of Set 11 | pangkalanbuun
# Processing Record 1 of Set 12 | assens
# Processing Record 2 of Set 12 | novikovo
# Processing Record 3 of Set 12 | yarada
# Processing Record 4 of Set 12 | botwood
# Processing Record 5 of Set 12 | porto velho
# Processing Record 6 of Set 12 | kroderen
# City not found. Skipping...
# Processing Record 7 of Set 12 | oriximina
# Processing Record 8 of Set 12 | kedgwick
# Processing Record 9 of Set 12 | linjiang
# Processing Record 10 of Set 12 | asilah
# Processing Record 11 of Set 12 | axim
# Processing Record 12 of Set 12 | san cristobal
# Processing Record 13 of Set 12 | simoes
# Processing Record 14 of Set 12 | geraldton
# Processing Record 15 of Set 12 | mahibadhoo
# Processing Record 16 of Set 12 | arrecife
# Processing Record 17 of Set 12 | mizdah
# Processing Record 18 of Set 12 | kasulu
# Processing Record 19 of Set 12 | broome
# Processing Record 20 of Set 12 | nilakkottai
# Processing Record 21 of Set 12 | carutapera
# Processing Record 22 of Set 12 | port lincoln
# Processing Record 23 of Set 12 | kyabram
# Processing Record 24 of Set 12 | vicente guerrero
# Processing Record 25 of Set 12 | paamiut
# Processing Record 26 of Set 12 | mercedes
# Processing Record 27 of Set 12 | majene
# Processing Record 28 of Set 12 | douentza
# Processing Record 29 of Set 12 | khristoforovo
# City not found. Skipping...
# Processing Record 30 of Set 12 | puerto madero
# Processing Record 31 of Set 12 | buraydah
# Processing Record 32 of Set 12 | saquisili
# Processing Record 33 of Set 12 | ulaanbaatar
# Processing Record 34 of Set 12 | tawau
# Processing Record 35 of Set 12 | tura
# Processing Record 36 of Set 12 | obigarm
# Processing Record 37 of Set 12 | outjo
# Processing Record 38 of Set 12 | opuwo
# Processing Record 39 of Set 12 | storslett
# Processing Record 40 of Set 12 | sola
# Processing Record 41 of Set 12 | maputo
# Processing Record 42 of Set 12 | bonthe
# Processing Record 43 of Set 12 | mbandaka
# Processing Record 44 of Set 12 | asau
# Processing Record 45 of Set 12 | puerto escondido
# Processing Record 46 of Set 12 | bodden town
# Processing Record 47 of Set 12 | stepnogorsk
# Processing Record 48 of Set 12 | korla
# Processing Record 49 of Set 12 | oistins
# Processing Record 50 of Set 12 | chom bung
# City not found. Skipping...
# Processing Record 1 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 2 of Set 13 | ranong
# Processing Record 3 of Set 13 | caarapo
# Processing Record 4 of Set 13 | goderich
# Processing Record 5 of Set 13 | itupiranga
# Processing Record 6 of Set 13 | bogorodskoye
# Processing Record 7 of Set 13 | seoul
# Processing Record 8 of Set 13 | the pas
# Processing Record 9 of Set 13 | ivanteyevka
# Processing Record 10 of Set 13 | wasilla
# Processing Record 11 of Set 13 | port moresby
# Processing Record 12 of Set 13 | llanes
# Processing Record 13 of Set 13 | nanortalik
# Processing Record 14 of Set 13 | terrace
# Processing Record 15 of Set 13 | biltine
# Processing Record 16 of Set 13 | isangel
# Processing Record 17 of Set 13 | mosquera
# Processing Record 18 of Set 13 | pemba
# Processing Record 19 of Set 13 | lithgow
# Processing Record 20 of Set 13 | bull savanna
# Processing Record 21 of Set 13 | lima
# Processing Record 22 of Set 13 | tromso
# Processing Record 23 of Set 13 | sibut
# Processing Record 24 of Set 13 | velke mezirici
# Processing Record 25 of Set 13 | san vicente
# Processing Record 26 of Set 13 | rudbar
# Processing Record 27 of Set 13 | pachino
# Processing Record 28 of Set 13 | necochea
# Processing Record 29 of Set 13 | teya
# Processing Record 30 of Set 13 | zhangye
# Processing Record 31 of Set 13 | alta floresta
# Processing Record 32 of Set 13 | gorontalo
# Processing Record 33 of Set 13 | richard toll
# City not found. Skipping...
# Processing Record 34 of Set 13 | bajo baudo
# City not found. Skipping...
# Processing Record 35 of Set 13 | tiznit
# Processing Record 36 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 37 of Set 13 | kupang
# Processing Record 38 of Set 13 | hollins
# Processing Record 39 of Set 13 | lakeside
# Processing Record 40 of Set 13 | shahr-e kord
# Processing Record 41 of Set 13 | matara
# Processing Record 42 of Set 13 | saint-francois
# Processing Record 43 of Set 13 | maimon
# City not found. Skipping...
# Processing Record 44 of Set 13 | key west
# Processing Record 45 of Set 13 | canto do buriti
# Processing Record 46 of Set 13 | tricase
# Processing Record 47 of Set 13 | shubarkuduk
# Processing Record 48 of Set 13 | tieli
# Processing Record 49 of Set 13 | beira
# Processing Record 50 of Set 13 | landeck
# Processing Record 1 of Set 14 | brandon
# Processing Record 2 of Set 14 | svetlyy
# Processing Record 3 of Set 14 | chumikan
# Processing Record 4 of Set 14 | tucuman
# Processing Record 5 of Set 14 | requena
# Processing Record 6 of Set 14 | vila do maio
# Processing Record 7 of Set 14 | myitkyina
# Processing Record 8 of Set 14 | general pico
# Processing Record 9 of Set 14 | tikhvin
# Processing Record 10 of Set 14 | cuamba
# Processing Record 11 of Set 14 | luang prabang
# Processing Record 12 of Set 14 | glendive
# Processing Record 13 of Set 14 | bathsheba
# Processing Record 14 of Set 14 | ankang
# Processing Record 15 of Set 14 | warrington
# Processing Record 16 of Set 14 | omboue
# Processing Record 17 of Set 14 | katobu
# Processing Record 18 of Set 14 | mount gambier
# Processing Record 19 of Set 14 | methoni
# Processing Record 20 of Set 14 | canmore
# Processing Record 21 of Set 14 | petatlan
# Processing Record 22 of Set 14 | estevan
# Processing Record 23 of Set 14 | kolokani
# Processing Record 24 of Set 14 | ilhabela
# Processing Record 25 of Set 14 | santa barbara
# Processing Record 26 of Set 14 | mitsamiouli
# Processing Record 27 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 28 of Set 14 | ozernovskiy
# Processing Record 29 of Set 14 | raymondville
# Processing Record 30 of Set 14 | kuryk
# Processing Record 31 of Set 14 | carupano
# Processing Record 32 of Set 14 | kaka
# Processing Record 33 of Set 14 | choya
# Processing Record 34 of Set 14 | aporawan
# City not found. Skipping...
# Processing Record 35 of Set 14 | chongoyape
# Processing Record 36 of Set 14 | newry
# Processing Record 37 of Set 14 | pandan
# Processing Record 38 of Set 14 | russell
# Processing Record 39 of Set 14 | graaff-reinet
# Processing Record 40 of Set 14 | odweyne
# Processing Record 41 of Set 14 | vao
# Processing Record 42 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 43 of Set 14 | vanimo
# Processing Record 44 of Set 14 | gat
# Processing Record 45 of Set 14 | sur
# Processing Record 46 of Set 14 | karakendzha
# City not found. Skipping...
# Processing Record 47 of Set 14 | kailua
# Processing Record 48 of Set 14 | rivera
# Processing Record 49 of Set 14 | kensington
# Processing Record 50 of Set 14 | mecca
# Processing Record 1 of Set 15 | traralgon
# Processing Record 2 of Set 15 | lokosovo
# Processing Record 3 of Set 15 | krasnyy chikoy
# Processing Record 4 of Set 15 | staryy nadym
# Processing Record 5 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 6 of Set 15 | zima
# Processing Record 7 of Set 15 | kasempa
# Processing Record 8 of Set 15 | duku
# Processing Record 9 of Set 15 | porto santo
# Processing Record 10 of Set 15 | isabela
# Processing Record 11 of Set 15 | birao
# Processing Record 12 of Set 15 | otavi
# Processing Record 13 of Set 15 | pedreiras
# Processing Record 14 of Set 15 | umm lajj
# Processing Record 15 of Set 15 | catumbela
# Processing Record 16 of Set 15 | crab hill
# City not found. Skipping...
# Processing Record 17 of Set 15 | iracoubo
# Processing Record 18 of Set 15 | realeza
# Processing Record 19 of Set 15 | flinders
# Processing Record 20 of Set 15 | vysokogornyy
# Processing Record 21 of Set 15 | ngunguru
# Processing Record 22 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 23 of Set 15 | pilikwe
# Processing Record 24 of Set 15 | eydhafushi
# Processing Record 25 of Set 15 | kaitangata
# Processing Record 26 of Set 15 | san jose
# Processing Record 27 of Set 15 | sunds
# Processing Record 28 of Set 15 | kandalaksha
# Processing Record 29 of Set 15 | tommot
# Processing Record 30 of Set 15 | sortavala
# Processing Record 31 of Set 15 | sarkand
# Processing Record 32 of Set 15 | wuwei
# Processing Record 33 of Set 15 | kayes
# Processing Record 34 of Set 15 | teknaf
# Processing Record 35 of Set 15 | canutama
# Processing Record 36 of Set 15 | tivaouane
# Processing Record 37 of Set 15 | caracollo
# Processing Record 38 of Set 15 | farias brito
# Processing Record 39 of Set 15 | mangit
# Processing Record 40 of Set 15 | ancud
# Processing Record 41 of Set 15 | rawson
# Processing Record 42 of Set 15 | shediac
# Processing Record 43 of Set 15 | crestview
# Processing Record 44 of Set 15 | gourcy
# Processing Record 45 of Set 15 | evans
# Processing Record 46 of Set 15 | laon
# Processing Record 47 of Set 15 | merauke
# Processing Record 48 of Set 15 | halifax
# Processing Record 49 of Set 15 | siguiri
# Processing Record 50 of Set 15 | natal
# Processing Record 1 of Set 16 | kandrian
# Processing Record 2 of Set 16 | charters towers
# Processing Record 3 of Set 16 | bowen
# Processing Record 4 of Set 16 | ostrovnoy
# Processing Record 5 of Set 16 | mozarlandia
# Processing Record 6 of Set 16 | diffa
# Processing Record 7 of Set 16 | banswada
# Processing Record 8 of Set 16 | makung
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Saint-Augustin  51.2260  -58.6502     15.12        72           4
# 1         Kaduqli  11.0167   29.7167     96.17         9          43
# 2          Kharan  28.5833   65.4167     76.15        10           3
# 3      Balkanabat  39.5108   54.3671     59.16        33          16
# 4       Jamestown  42.0970  -79.2353     57.99        35           1
# 5         Florida  28.7505  -82.5001     79.00        69          40
# 6  Port Elizabeth -33.9180   25.5701     77.00        61           0
# 7      Bredasdorp -34.5322   20.0403     78.80        38           8
# 8          Yulara -25.2406  130.9889     69.80        32           0
# 9         Dunedin -45.8742  170.5036     54.00        91          97
#
#    Wind Speed Country Current Description
# 0       22.86      CA           clear sky
# 1       10.33      SD    scattered clouds
# 2       13.15      PK           clear sky
# 3        7.96      TM          few clouds
# 4       16.98      US           clear sky
# 5        5.75      US    scattered clouds
# 6        8.05      ZA           clear sky
# 7       20.71      ZA           clear sky
# 8        8.05      AU           clear sky
# 9        3.62      NZ     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
